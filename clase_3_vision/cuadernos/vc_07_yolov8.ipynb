# %%
from ultralytics import YOLO
from PIL import Image
import cv2

model = YOLO("yolov8n.pt")
# accepts all formats - image/dir/Path/URL/video/PIL/ndarray. 0 for webcam
results = model.predict(source="0") # Display preds. Accepts all YOLO predict arguments
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1280x720 at 30.00 FPS)
#
# 0: 384x640 (no detections), 57.3ms
# 0: 384x640 1 person, 52.5ms
# 0: 384x640 1 person, 53.2ms
# 0: 384x640 1 person, 51.8ms
# 0: 384x640 1 person, 53.3ms
# 0: 384x640 1 person, 1 chair, 53.6ms
# 0: 384x640 1 person, 51.7ms
# 0: 384x640 1 person, 53.1ms
# 0: 384x640 1 person, 51.7ms
# 0: 384x640 1 person, 50.3ms
# 0: 384x640 1 person, 50.8ms
# 0: 384x640 1 person, 1 chair, 50.7ms
# 0: 384x640 1 person, 50.7ms
# 0: 384x640 1 person, 52.3ms
# 0: 384x640 1 person, 53.9ms
# 0: 384x640 1 person, 56.8ms
# 0: 384x640 1 person, 55.6ms
# 0: 384x640 1 person, 54.8ms
# 0: 384x640 1 person, 55.3ms
# 0: 384x640 1 person, 54.2ms
# 0: 384x640 1 person, 54.5ms
# 0: 384x640 1 person, 53.8ms
# 0: 384x640 1 person, 58.3ms
# 0: 384x640 1 person, 55.3ms
# 0: 384x640 1 person, 53.8ms
# 0: 384x640 1 person, 54.5ms
# 0: 384x640 1 person, 53.3ms
# 0: 384x640 1 person, 52.8ms
# 0: 384x640 1 person, 54.9ms
# 0: 384x640 1 person, 53.0ms
# 0: 384x640 1 person, 54.5ms
# 0: 384x640 1 person, 56.3ms
# 0: 384x640 1 person, 55.6ms
# 0: 384x640 1 person, 54.5ms
# 0: 384x640 1 person, 53.5ms
# 0: 384x640 1 person, 51.8ms
# 0: 384x640 1 person, 52.4ms
# 0: 384x640 1 person, 52.6ms
# 0: 384x640 1 person, 53.4ms
# 0: 384x640 1 person, 52.1ms
# 0: 384x640 1 person, 55.9ms
# 0: 384x640 1 person, 53.3ms
# 0: 384x640 1 person, 52.8ms
# 0: 384x640 1 person, 53.1ms
# 0: 384x640 1 person, 51.9ms
# 0: 384x640 1 person, 49.8ms
# 0: 384x640 1 person, 55.6ms
# 0: 384x640 1 person, 52.9ms
# 0: 384x640 1 person, 51.9ms
# 0: 384x640 1 person, 51.2ms
# 0: 384x640 1 person, 50.3ms
# 0: 384x640 1 person, 52.7ms
# 0: 384x640 1 person, 50.3ms
# 0: 384x640 1 person, 51.8ms
# 0: 384x640 1 person, 56.4ms
# 0: 384x640 1 person, 52.5ms
# 0: 384x640 1 person, 52.8ms
# 0: 384x640 1 person, 1 bed, 54.5ms
# 0: 384x640 1 person, 53.1ms
# 0: 384x640 1 person, 52.6ms
# 0: 384x640 1 person, 54.7ms
# 0: 384x640 1 person, 57.2ms
# 0: 384x640 1 person, 59.5ms
# 0: 384x640 1 person, 60.0ms
# 0: 384x640 1 person, 65.5ms
# 0: 384x640 1 person, 66.8ms
# 0: 384x640 2 persons, 78.5ms
# 0: 384x640 2 persons, 63.4ms
# 0: 384x640 2 persons, 61.0ms
# 0: 384x640 3 persons, 60.5ms
# 0: 384x640 2 persons, 62.7ms
# 0: 384x640 2 persons, 52.3ms
# 0: 384x640 3 persons, 53.4ms
# 0: 384x640 2 persons, 51.6ms
# 0: 384x640 2 persons, 52.5ms
# 0: 384x640 2 persons, 52.8ms
# 0: 384x640 2 persons, 52.2ms
# 0: 384x640 2 persons, 51.6ms
# 0: 384x640 2 persons, 51.5ms
# 0: 384x640 2 persons, 52.5ms
# 0: 384x640 2 persons, 52.9ms
# 0: 384x640 1 person, 56.9ms
# 0: 384x640 2 persons, 51.5ms
# 0: 384x640 1 person, 51.7ms
# 0: 384x640 1 person, 52.7ms
# 0: 384x640 1 person, 52.1ms
# 0: 384x640 1 person, 51.4ms
# 0: 384x640 1 person, 49.7ms
# 0: 384x640 1 person, 47.9ms
# 0: 384x640 1 person, 56.0ms
# 0: 384x640 1 person, 52.0ms
# 0: 384x640 1 person, 52.0ms
# 0: 384x640 1 person, 52.1ms
# 0: 384x640 1 person, 50.3ms
# 0: 384x640 1 person, 52.2ms
# 0: 384x640 1 person, 49.5ms
# 0: 384x640 1 person, 49.8ms
# 0: 384x640 1 person, 51.1ms
# 0: 384x640 1 person, 53.0ms
# 0: 384x640 1 person, 51.9ms
# 0: 384x640 1 person, 52.7ms
# 0: 384x640 1 person, 52.0ms
# 0: 384x640 1 person, 53.2ms
# 0: 384x640 1 person, 51.1ms
# 0: 384x640 1 person, 52.1ms
# 0: 384x640 1 person, 51.8ms
# 0: 384x640 1 person, 52.0ms
# 0: 384x640 1 person, 50.4ms
# 0: 384x640 1 person, 51.4ms
# 0: 384x640 2 persons, 53.4ms
# 0: 384x640 1 person, 53.7ms
# 0: 384x640 1 person, 51.9ms
# 0: 384x640 1 person, 53.0ms
# 0: 384x640 1 person, 51.0ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 model = YOLO("yolov8n.pt")
#       6 # accepts all formats - image/dir/Path/URL/video/PIL/ndarray. 0 for webcam
# ----> 7 results = model.predict(source="0") # Display preds. Accepts all YOLO predict arguments
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/model.py:221, in YOLO.predict(self, source, stream, **kwargs)
#     219 else:  # only update args if predictor is already setup
#     220     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 221 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:114, in BasePredictor.__call__(self, source, model, stream)
#     112     return self.stream_inference(source, model)
#     113 else:
# --> 114     return list(self.stream_inference(source, model))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/utils/_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:172, in BasePredictor.stream_inference(self, source, model)
#     170 # inference
#     171 with self.dt[1]:
# --> 172     preds = self.model(im, augment=self.args.augment, visualize=visualize)
#     174 # postprocess
#     175 with self.dt[2]:
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/autobackend.py:307, in AutoBackend.forward(self, im, augment, visualize)
#     304     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     306 if self.pt or self.nn_module:  # PyTorch
# --> 307     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     308 elif self.jit:  # TorchScript
#     309     y = self.model(im)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/tasks.py:199, in DetectionModel.forward(self, x, augment, profile, visualize)
#     197 if augment:
#     198     return self._forward_augment(x)  # augmented inference, None
# --> 199 return self._forward_once(x, profile, visualize)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/tasks.py:58, in BaseModel._forward_once(self, x, profile, visualize)
#      56 if profile:
#      57     self._profile_one_layer(m, x, dt)
# ---> 58 x = m(x)  # run
#      59 y.append(x if m.i in self.save else None)  # save output
#      60 if visualize:
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules.py:193, in C2f.forward(self, x)
#     191 def forward(self, x):
#     192     y = list(self.cv1(x).chunk(2, 1))
# --> 193     y.extend(m(y[-1]) for m in self.m)
#     194     return self.cv2(torch.cat(y, 1))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules.py:193, in <genexpr>(.0)
#     191 def forward(self, x):
#     192     y = list(self.cv1(x).chunk(2, 1))
# --> 193     y.extend(m(y[-1]) for m in self.m)
#     194     return self.cv2(torch.cat(y, 1))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules.py:131, in Bottleneck.forward(self, x)
#     130 def forward(self, x):
# --> 131     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules.py:37, in Conv.forward_fuse(self, x)
#      36 def forward_fuse(self, x):
# ---> 37     return self.act(self.conv(x))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
