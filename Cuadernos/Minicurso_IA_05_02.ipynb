# %% [markdown]
# <figure>
# <img src="../Imagenes/logo-final-ap.png"  width="80" height="80" align="left"/>
# </figure>
#
# # <span style="color:blue"><left>Aprendizaje Profundo</left></span>

# %% [markdown]
# # <span style="color:red"><center>Minicurso  de Inteligencia Artificial<center></span>

# %% [markdown]
# ## <span style="color:green"><center>Introducción a Modelos de Lenguaje Natural: Aplicaciones</center></span>

# %% [markdown]
# ##   <span style="color:blue">Profesores</span>

# %% [markdown]
# 1. Alvaro  Montenegro, PhD, ammontenegrod@unal.edu.co
# 2. Daniel  Montenegro, Msc, dextronomo@gmail.com
# 1. Oleg Jarma, Estadístico, ojarmam@unal.edu.co

# %% [markdown]
# ##   <span style="color:blue">Asesora Medios y Marketing digital</span>

# %% [markdown]
# 4. Maria del Pilar Montenegro, pmontenegro88@gmail.com

# %% [markdown]
# ## <span style="color:blue">Contenido</span>

# %% [markdown]
# ## <span style="color:blue">Enlaces importantes</span>

# %% [markdown]
# 1. [Repositorio del mini curso](https://github.com/AprendizajeProfundo/Curso-Basico-IA)
# 1. [Repositorio Aprendizaje Profundo](https://github.com/AprendizajeProfundo)
# 1. [Clases en vivo](https://us02web.zoom.us/j/86057731334?pwd=MlgvU1cwZmtXbnBBSjVodmNaTDFLQT09), Meeting ID: 860 5773 1334, Passcode: 392083
# 1. [Clases grabadas](https://aprendizajeprofundo.co/cursoslibres/)

# %% [markdown]
# ## <span style="color:blue">Embeddings de Frases</span>

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

#Our sentences we like to encode
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.', 
    'The quick brown fox jumps over the lazy dog.']

#Sentences are encoded by calling model.encode()
sentence_embeddings = model.encode(sentences)

#Print the embeddings
for sentence, embedding in zip(sentences, sentence_embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Sentence: This framework generates embeddings for each input sentence
# Embedding: [-1.37173347e-02 -4.28515598e-02 -1.56286173e-02  1.40537722e-02
#   3.95537466e-02  1.21796302e-01  2.94333957e-02 -3.17524150e-02
#   3.54959853e-02 -7.93140382e-02  1.75878294e-02 -4.04369831e-02
#   4.97259423e-02  2.54912432e-02 -7.18700513e-02  8.14968646e-02
#   1.47073157e-03  4.79626991e-02 -4.50335704e-02 -9.92174894e-02
#  -2.81769745e-02  6.45045936e-02  4.44670729e-02 -4.76217046e-02
#  -3.52952369e-02  4.38671708e-02 -5.28566130e-02  4.33081470e-04
#   1.01921536e-01  1.64072644e-02  3.26996967e-02 -3.45986597e-02
#   1.21339224e-02  7.94871077e-02  4.58344771e-03  1.57778673e-02
#  -9.68208257e-03  2.87626181e-02 -5.05806580e-02 -1.55793484e-02
#  -2.87907198e-02 -9.62280203e-03  3.15556750e-02  2.27349326e-02
#   8.71449858e-02 -3.85027714e-02 -8.84718522e-02 -8.75498541e-03
#  -2.12343540e-02  2.08923984e-02 -9.02078077e-02 -5.25732301e-02
#  -1.05639063e-02  2.88311131e-02 -1.61454864e-02  6.17837487e-03
#  -1.23234419e-02 -1.07337004e-02  2.83353906e-02 -5.28567731e-02
#   6.91623911e-02 -4.24114875e-02 -4.67682667e-02 -3.64751220e-02
#   4.50400114e-02  6.09816872e-02 -6.56561479e-02 -5.45640104e-03
#  -1.86226927e-02 -6.31484613e-02 -3.87436487e-02  3.46733183e-02
#   5.55458255e-02  5.21628261e-02  5.61065301e-02  1.02063961e-01]

# %% [markdown]
# ## <span style="color:blue">Similitud de Frases</span>

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

#Sentences are encoded by calling model.encode()
emb1 = model.encode("This is a red cat with a hat.")
emb2 = model.encode("Have you seen my red cat?")

cos_sim = util.cos_sim(emb1, emb2)
print("Cosine-Similarity:", cos_sim)
# Out:
# Cosine-Similarity: tensor([[0.6153]])

# %% [markdown]
# ## <span style="color:blue">Similitud de Frases en Español</span>

# %%
#model_es = ft.load_model(f'{ruta_global}/Modelos/cc.es.300.bin')
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# %%
import numpy as np

ab = model.encode('Abogada')
ab2 = model.encode('Abogado')

sim = np.dot(ab,ab2)/(np.linalg.norm(ab)*np.linalg.norm(ab2))
print(sim)
# Out:
# 0.9791771

# %% [markdown]
# ## <span style="color:blue">Cross-Encoding</span>

# %%
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-12-v2', max_length=512)

#For Example
scores = model.predict([('How many people live in Berlin?', 'Berlin had a population of 3,520,031 registered inhabitants in an area of 891.82 square kilometers.'), 
                        ('How many people live in Berlin?', 'Berlin is well known for its museums.')])
# Out:
# Downloading:   0%|          | 0.00/791 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/127M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
scores
# Out:
# array([ 9.218912 , -4.0780306], dtype=float32)

# %%
from sentence_transformers import CrossEncoder
model = CrossEncoder('cross-encoder/nli-deberta-v3-base')
scores = model.predict([('A man is eating pizza', 'A man eats something'), ('A black race car is driving a crowd of people.', 'A man is driving down a lonely road.')])

#Convert scores to labels
label_mapping = ['contradiction', 'entailment', 'neutral']
labels = [label_mapping[score_max] for score_max in scores.argmax(axis=1)]

# %%
scores
# Out:
# array([[-5.3367224 ,  3.5204763 ,  0.81518734],
#        [ 7.6596756 , -4.344041  , -2.8041697 ]], dtype=float32)

# %%
labels
# Out:
# ['entailment', 'contradiction']

# %% [markdown]
# ## <span style="color:blue">Wago </span>

# %% [markdown]
# ## Librerías Necesarias

# %%
##### VOZ ######
# Text-to-Speech Conversion
import pyttsx3 as tts
# Reconocimiento de Voz
import speech_recognition

##### CHATBOT ######
# Intenciones y funcionalidad de chatbot
from neuralintents import GenericAssistant
# Manejo general del sistema
import sys
# Traducir texto, resumir texto
from transformers import pipeline
# Manejo de vectores
import numpy as np
# Calcular similaridad
import spacy

#######FUENTES DE INFORMACION Y PROCESAMIENTO#######
# Modulo para extraer noticias de Google News
from gnewsclient import gnewsclient
# Acceder a contenido de internet
import requests
# Acceder al texto dentro del html
from bs4 import BeautifulSoup
# Convertir html a texto
import html2text
# Analizar expresiones regulares
import re

# %% [markdown]
# ## Asistente de Voz

# %% [markdown]
# ### Voces Disponibles

# %%
# Inciar objeto text-to-speech
speaker = tts.init()
# Obtener voces disponibles del sistema
voices = speaker.getProperty('voices')
# Obtener voces en español
voices_esp = []
print('\nVoces disponibles en Español:\n')

for voice in voices:
    if str(voice.languages).find('es')>0:
        print("Voice: %s" % voice.name)
        print(" - ID: %s" % voice.id)
        print(" - Languages: %s" % voice.languages)
        print(" - Gender: %s" % voice.gender)
        print(" - Age: %s" % voice.age)
        print("\n")
        voices_esp.append(voice)

# Elegir español (VARIA EN SISTEMA OPERATIVO)
#azar = np.random.randint(len(voices_esp))
azar=-1
eleccion = voices_esp[azar].id
print("Eligiendo idioma:",eleccion)
speaker.setProperty("voice", eleccion)
# Out:
# Voces disponibles en Español:
#
# Voice: Diego
#  - ID: com.apple.speech.synthesis.voice.diego.premium
#  - Languages: ['es_AR']
#  - Gender: VoiceGenderMale
#  - Age: 30
#
#
# Voice: Jorge
#  - ID: com.apple.speech.synthesis.voice.jorge
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderMale
#  - Age: 35
#
#
# Voice: Juan
#  - ID: com.apple.speech.synthesis.voice.juan.premium
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderMale
#  - Age: 30
#
#
# Voice: Monica
#  - ID: com.apple.speech.synthesis.voice.monica.premium
#  - Languages: ['es_ES']
#  - Gender: VoiceGenderFemale
#  - Age: 30
#
#
# Voice: Paulina
#  - ID: com.apple.speech.synthesis.voice.paulina.premium
#  - Languages: ['es_MX']
#  - Gender: VoiceGenderFemale
#  - Age: 30
#
#
# Eligiendo idioma: com.apple.speech.synthesis.voice.paulina.premium

# %% [markdown]
# ### Pruebas iniciales - Asistente en Acción

# %%
# Por si el speaker se queda en loop
if speaker._inLoop:
    speaker.endLoop()

# Asistente hablando
speaker.say("Hola mundo, ¡estoy viva!")
# Reproducir sonido y parar
speaker.runAndWait()

# %% [markdown]
# ## Reconocimiento de Audio

# %%
# Iniciar reconocimiento de voz
recognizer=speech_recognition.Recognizer()

# %% [markdown]
# ### Pruebas iniciales - Reconocimiento en Acción

# %%
import os
import shutil

# %% [markdown]
# ## Ajustes para Mac M1

# %%
print("PATH inicial:\n")
print(os.environ['PATH'],end='\n\n')
os.environ['PATH']+=':/opt/homebrew/Cellar/flac/1.3.3/bin/'
print('PATH modificado:\n')
print(os.environ['PATH'],end='\n\n')
path = os.getenv('PATH')
print("shutil.which nos brinda la localización: %s" % (shutil.which('flac')))
# Out:
# PATH inicial:
#
# /Users/moury/miniforge3/envs/transformers/bin:/Users/moury/miniforge3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin
#
# PATH modificado:
#
# /Users/moury/miniforge3/envs/transformers/bin:/Users/moury/miniforge3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin:/opt/homebrew/Cellar/flac/1.3.3/bin/
#
# shutil.which nos brinda la localización: /Users/moury/miniforge3/envs/transformers/bin/flac

# %% [markdown]
# ## Speech Recognition

# %%
# Asistente hablando
speaker.say("Por favor, dime algo y te lo traduzco a texto:")
# Reproducir sonido y parar
speaker.runAndWait()

# %%
# Abrir Micrófono
with speech_recognition.Microphone() as mic:
    # Reducir ruido ambiental
    recognizer.adjust_for_ambient_noise(mic,duration=0.5)
    print("Escuchando Audio...",end=' ')
    # Escuchar audio
    audio=recognizer.listen(mic)
    print("Audio Escuchado.",end=' ')
    # Reconocer audio
    print("Traduciendo a Texto...\n")
    texto=recognizer.recognize_google(audio,language="es-CO")

# Visualizar audio en texto
print("Audio reconocido:", texto)

# Asistente hablando
speaker.say(texto)
# Reproducir sonido y parar
speaker.runAndWait()
# Out:
# Escuchando Audio... Audio Escuchado. Traduciendo a Texto...
#
# Audio reconocido: Hola

# %% [markdown]
# ##  Prueba con Audio Grabado

# %% [markdown]
# En Mac M1 no hay permisos para abrir el puerto de audio.
#
# Sin embargo, en otros OS debería funcionar el siguiente snippet sin problema:
#
# ```
# import sounddevice as sd
#
# from scipy.io.wavfile import write
#
# fs = 44100  # Sample rate
# seconds = 5  # Duration of recording
#
# myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
# sd.wait()  # Wait until recording is finished
# write('audio_test.wav', fs, myrecording)  # Save as WAV file
# ```

# %%
audio_grabado = 'audio_test_cancion_2.wav'

# %%
#Need to install sounddevice
import sounddevice as sd
from scipy.io import wavfile as wav
from IPython.display import Audio

scipy_sample_rate, scipy_audio = wav.read(audio_grabado)
Audio(scipy_audio, rate=scipy_sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with speech_recognition.AudioFile(audio_grabado) as fuente:
    
    recognizer.adjust_for_ambient_noise(fuente,duration=1)
    audio = recognizer.listen(fuente)
    texto = recognizer.recognize_google(audio,language="es-CO")

print("Audio Convertido a Texto es:\n")
print(texto)

if speaker._inLoop:
    speaker.endLoop()
# Asistente hablando
speaker.say(texto)
# Reproducir sonido y parar
speaker.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# /var/folders/d_/hfs18jf54371qfmf54zq289c0000gn/T/ipykernel_2867/1041536346.py in <module>
#       3     #recognizer.adjust_for_ambient_noise(fuente,duration=1)
#       4     audio = recognizer.listen(fuente)
# ----> 5     texto = recognizer.recognize_google(audio,language="es-CO")
#       6
#       7 print("Audio Convertido a Texto es:\n")
#
# ~/miniforge3/envs/transformers/lib/python3.9/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     856         # return results
#     857         if show_all: return actual_result
# --> 858         if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     859
#     860         if "confidence" in actual_result["alternative"]:
#
# UnknownValueError:

# %% [markdown]
# ## Pruebas De Pregunta-Respuesta

# %%
# Flag para parar acción
done = False

while not done:
    try:
        with speech_recognition.Microphone() as mic:
            
            recognizer.adjust_for_ambient_noise(mic,duration=0.5)
            audio=recognizer.listen(mic)
            texto=recognizer.recognize_google(audio,language="es-CO") #item
            #print(1)
            
            # Poner transformer aquí
            
            
            if speaker._inLoop:
                speaker.endLoop()
            
            speaker.say("Dijiste: " + texto)
            speaker.runAndWait()
            # Pasar texto a minúscula
            texto=texto.lower()
            print("Dijiste:",texto)

    # Maquina no entender
    except speech_recognition.UnknownValueError:
        recognizer=speech_recognition.Recognizer()
        
        if speaker._inLoop:
            speaker.endLoop()
        # Pedir info de nuevo
        speaker.say("No entendí lo que dijiste, ¿por favor podrías repetir?")
        speaker.runAndWait()
    # Desactivar acciones con palabra clave
    if texto=='chao':
        if speaker._inLoop:
            speaker.endLoop()
        # Frase de despedida
        speaker.say("Chao pescao. Nos vemos por ahí.")
        speaker.runAndWait()
        done=True
# Out:
# Dijiste: chao

# %% [markdown]
# # Mapeo

# %%
def hola():
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("Hola, en que puedo ayudarte?")
    speaker.runAndWait()

# %%
def salir():
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("Chao pescao. Nos vemos por ahí.")
    speaker.runAndWait()
    sys.exit()

# %%
def noticia():
    from gnewsclient import gnewsclient
    
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("Claro que sí. Encontré estos temas:")
    speaker.runAndWait()
    # declare a NewsClient object 
    client = gnewsclient.NewsClient(language='spanish', location='Colombia', max_results=5)
    temas = client.topics
    print("\nTemas:\n")
    for i in range(len(temas)):
        print('- ',temas[i])
        
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say(', '.join(temas))
    speaker.runAndWait()
    
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("¿Cuál tema te gustaría escuchar?")
    speaker.runAndWait()

# %%
def temas():
    from gnewsclient import gnewsclient
    client = gnewsclient.NewsClient(language='spanish', location='Colombia', topic=message, max_results=5)
    # get news feed
    global noticias #MALO
    noticias = client.get_news()
    for i in range(len(noticias)):
        print(noticias[i]['title'],'\n')
        
        if speaker._inLoop:
            speaker.endLoop()
        speaker.say(noticias[i]['title'])
        speaker.runAndWait()
        print(noticias[i]['link'],'\n')
        
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("¿Cuál te gustaría escuchar?")
    speaker.runAndWait()

# %%
def resumen():
    
    import numpy as np
    from transformers import pipeline
    from sentence_utils import split_into_sentences
    
    if speaker._inLoop:
        speaker.endLoop()
    speaker.say("Okey. ¡Qué perezoso!, dame un momento mientras inicio el transformer")
    speaker.runAndWait()
    
    # ultimo numero es la noticia elegida
    noticia_elegida = int(message.split()[-1])-1
    # Obtener link
    url = noticias[noticia_elegida]['link']
    # Obtener conexión
    res = requests.get(url)
    
    print("Extrayendo Noticia")
    speaker.say("Extrayendo Noticia")
    speaker.runAndWait()
    # Obtener contenido
    html_page = res.content
    # Extraer Noticia
    soup = BeautifulSoup(html_page, 'html.parser')
    # Extraer texto
    text = soup.find_all('p')
    # Preprocesamiento
    texto = [texts for texts in list(text) if len(texts)>2]
    
    print("Leyendo Noticia")
    speaker.say("Leyendo Noticia")
    speaker.runAndWait()
    # Limpiar Noticia
    texto_limpio = html2text.html2text(''.join(str(texto[2:])))
    #print(texto_limpio)
    texto_limpio = re.sub(r'\([^)]*\)',' ',texto_limpio)
    texto_limpio = re.sub(r'\n','  ',texto_limpio)
    texto_limpio = re.sub(r'\*',' ',texto_limpio)
    
    # Traducir Noticia al inglés
    print("Traduciendo Noticia al inglés")
    speaker.say("Traduciendo Noticia al inglés")
    speaker.runAndWait()
    translator = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")
    # Separar noticia en frases (Mayor rapidez)
    frase = split_into_sentences(texto_limpio)
    # traducir frase
    sentence = translator(frase)
    # Unir frases
    todo_texto = [sentences['translation_text'] for sentences in sentence]
    todo_texto = ' '.join(todo_texto)
    
    
    # Resumir Noticia
    print("Resumiendo Noticia")
    speaker.say("Resumiendo Noticia")
    speaker.runAndWait()
    summarizer = pipeline("summarization")
    resumen = summarizer(todo_texto)
    resumen_en = resumen[0]['summary_text']
    
    # Traducir resumen a español
    print("Traduciendo de vuelta al español...") 
    speaker.say("Traduciendo de vuelta al español...")    
    speaker.runAndWait()
    translator_en_es = pipeline("translation", model="Helsinki-NLP/opus-mt-en-es")
    resumen_es_list = translator_en_es(resumen_en)
    resumen_es = resumen_es_list[0]['translation_text']
    
    # Decir y escribir resumen
    print(resumen_es)
    speaker.say(resumen_es)
    speaker.runAndWait()
    
    '''
    # declare a NewsClient object 
    with open('resumen_es.txt') as f:
        lines = f.readlines()
    print(lines)
    speaker.say(lines)
    speaker.runAndWait()'''

# %%
# Mappings pregunta-respuesta
mappings={
    "inicio":hola,
    "salir": salir,
    "noticias":noticia,
    "resumen":resumen,
    "temas":temas
}

# %%
assistant=GenericAssistant('palabras.json',intent_methods=mappings)
assistant.train_model()
# Out:
# /Users/moury/Documents/2021/Test_Mac_M1/Notebooks/neuralintents/main.py:97: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# Metal device set to: Apple M1

# %%
from IPython.display import clear_output

while True:
    try:
        with speech_recognition.Microphone() as mic:
            recognizer.adjust_for_ambient_noise(mic,duration=0.5)
            print("Escuchando...",end=' ')
            audio=recognizer.listen(mic)
            print("Reconociendo...")
            message=recognizer.recognize_google(audio,language="es-CO")
            message=message.lower()
            print(message)
        assistant.request(message)
        
    except speech_recognition.UnknownValueError:
        print("Error. Reiniciando Recognizer...\n")
        recognizer=speech_recognition.Recognizer()
# Out:
# Escuchando... Reconociendo...
# hola cómo estás
# Escuchando... Reconociendo...
# las noticias
#
# Temas:
#
# -  Top Stories
# -  World
# -  Nation
# -  Business
# -  Technology
# -  Entertainment
# -  Sports
# -  Science
# -  Health
# Escuchando... Reconociendo...
# Error. Reiniciando Recognizer...
#
# Escuchando... Reconociendo...
# world mundo a veces fallo un poco porque hay mucho ruido ambiental mundo
# Día libre para funcionarios públicos que completen vacunación en diciembre - El Colombiano
#
# https://news.google.com/__i/rss/rd/articles/CBMiggFodHRwczovL3d3dy5lbGNvbG9tYmlhbm8uY29tL2NvbG9tYmlhL3NhbHVkL2RpYS1saWJyZS1wYXJhLXRyYWJhamFkb3Jlcy1xdWUtY29tcGxldGVuLWVzcXVlbWEtZGUtdmFjdW5hY2lvbi1lbi1jb2xvbWJpYS1IRzE2MTAxMzYz0gEA?oc=5
#
# Las claves económicas de Colombia en el 2022, según la Ocde - Portafolio.co
#
# https://news.google.com/__?oc=5
#
# Detectan el primer caso con la variante ómicron de COVID-19 en Estados Unidos - Pulzo
#
# https://news.google.com/__?oc=5
#
# Se aplaza la reapertura de la frontera entre Colombia y Ecuador: ya no es este miércoles - Semana.com
#
# https://news.google.com/__...?oc=5
#
# Una bomba de la Segunda Guerra Mundial explota y deja 4 heridos en Alemania - BBC Mundo
#
# https://news.google.com/__i/rss/rd/articles/CBMiOWh0dHBzOi8vd3d3LmJiYy5jb20vbXVuZG8vbm90aWNpYXMtaW50ZXJuYWNpb25hbC01OTQ5NzI5MtIBPWh0dHBzOi8vd3d3LmJiYy5jb20vbXVuZG8vbm90aWNpYXMtaW50ZXJuYWNpb25hbC01OTQ5NzI5Mi5hbXA?oc=5
#
# Escuchando... Reconociendo...
# resume las 5
# Extrayendo Noticia
# Leyendo Noticia
# Traduciendo Noticia al inglés
# Resumiendo Noticia
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Your max_length is set to 142, but you input_length is only 32. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Traduciendo de vuelta al español...
# La BBC no es responsable del contenido de este artículo . Nos complace aclarar nuestra posición en relación con la situación en el Reino Unido . Acogemos con beneplácito el desarrollo de la primera planta de energía nuclear del Reino Unido en los Estados Unidos para utilizar la tecnología para desarrollar un reactor nuclear en el futuro .
# Escuchando... Reconociendo...
# los dejo tengo que seguir en el diplomado
#
# Temas:
#
# -  Top Stories
# -  World
# -  Nation
# -  Business
# -  Technology
# -  Entertainment
# -  Sports
# -  Science
# -  Health
# Escuchando... Reconociendo...
# Error. Reiniciando Recognizer...
#
# Escuchando...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/d_/hfs18jf54371qfmf54zq289c0000gn/T/ipykernel_2655/3621247249.py in <module>
#       6             recognizer.adjust_for_ambient_noise(mic,duration=0.5)
#       7             print("Escuchando...",end=' ')
# ----> 8             audio=recognizer.listen(mic)
#       9             print("Reconociendo...")
#      10             message=recognizer.recognize_google(audio,language="es-CO")
#
# ~/miniforge3/envs/transformers/lib/python3.9/site-packages/speech_recognition/__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# ~/miniforge3/envs/transformers/lib/python3.9/site-packages/speech_recognition/__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# ~/miniforge3/envs/transformers/lib/python3.9/site-packages/pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:

# %% [markdown]
# heatlh=3,deportes=2

# %% [markdown]
# ## Noticias

# %%
topic='Health'

# %%
# declare a NewsClient object 
client = gnewsclient.NewsClient(language='spanish', location='Colombia', topic=topic, max_results=5)
print(client.topics)
# Out:
# ['Top Stories', 'World', 'Nation', 'Business', 'Technology', 'Entertainment', 'Sports', 'Science', 'Health']

# %%
# get news feed
noticias = client.get_news()
noticias
# Out:
# [{'title': '¿Qué vacuna me puedo aplicar y cuándo?, vea todo lo que debe saber sobre la tercera dosis - El País Cali',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMie2h0dHBzOi8vd3d3LmVscGFpcy5jb20uY28vc2FsdWQvcXVlLXZhY3VuYS1tZS1wdWVkby1hcGxpY2FyLXktY3VhbmRvLXZlYS10b2RvLWxvLXF1ZS1kZWJlLXNhYmVyLXNvYnJlLWxhLXRlcmNlcmEtZG9zaXMuaHRtbNIBAA?oc=5',
#   'media': None},
#  {'title': "Variante Delta del covid ya 'manda' en el Valle, ¿cuál puede ser su impacto? - El País Cali",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMieGh0dHBzOi8vd3d3LmVscGFpcy5jb20uY28vY29udGVuaWRvLXByZW1pdW0vdmFyaWFudGUtZGVsdGEtZGVsLWNvdmlkLXlhLW1hbmRhLWVuLWVsLXZhbGxlLWN1YWwtcHVlZGUtc2VyLXN1LWltcGFjdG8uaHRtbNIBAA?oc=5',
#   'media': None},
#  {'title': 'Padres de menores con enfermedad terminal tendrán licencia 10 días hábiles - Caracol Radio',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiR2h0dHBzOi8vY2FyYWNvbC5jb20uY28vcmFkaW8vMjAyMS8xMS8yNC9wb2xpdGljYS8xNjM3NzU3MTU4XzU2NDA1OC5odG1s0gFLaHR0cHM6Ly9jYXJhY29sLmNvbS5jby9yYWRpby8yMDIxLzExLzI0L3BvbGl0aWNhLzE2Mzc3NTcxNThfNTY0MDU4LmFtcC5odG1s?oc=5',
#   'media': None},
#  {'title': 'Ahora Pfizer apuesta por la telemedicina en Colombia - Portafolio.co',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'Tips para combatir la obesidad - La FM',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiTWh0dHBzOi8vd3d3LmxhZm0uY29tLmNvL2VzdGlsby1kZS12aWRhL3F1ZS1jb21pZGEtcG9kcmlhLWNvbWJhdGlyLWxhLW9iZXNpZGFk0gFRaHR0cHM6Ly93d3cubGFmbS5jb20uY28vZXN0aWxvLWRlLXZpZGEvcXVlLWNvbWlkYS1wb2RyaWEtY29tYmF0aXItbGEtb2Jlc2lkYWQ_YW1w?oc=5',
#   'media': None}]

# %%
noticias[4]
# Out:
# {'title': 'Presidente Duque expresa solidaridad a Perú por terremoto y ofrece ayuda - Caracol Radio',
#  'link': 'https://news.google.com/__i/rss/rd/articles/CBMiR2h0dHBzOi8vY2FyYWNvbC5jb20uY28vcmFkaW8vMjAyMS8xMS8yOC9uYWNpb25hbC8xNjM4MTE5NTQwXzk3MzQ2My5odG1s0gFLaHR0cHM6Ly9jYXJhY29sLmNvbS5jby9yYWRpby8yMDIxLzExLzI4L25hY2lvbmFsLzE2MzgxMTk1NDBfOTczNDYzLmFtcC5odG1s?oc=5',
#  'media': None}

# %%
print(noticias[4]['title'])
speaker.say(noticias[4]['title'])
speaker.runAndWait()
# Out:
# Por ley, se regulará en colegios el uso de celular hasta noveno grado - El Espectador

# %%
noticia_elegida = 4

# %%
url = noticias[noticia_elegida]['link']

res = requests.get(url)
html_page = res.content

soup = BeautifulSoup(html_page, 'html.parser')
text = soup.find_all('p')
#text

# %%
texto = [texts for texts in list(text) if len(texts)>2]

# %%
texto_limpio = html2text.html2text(''.join(str(texto[2:])))
#print(texto_limpio)
texto_limpio = re.sub(r'\([^)]*\)',' ',texto_limpio)
texto_limpio = re.sub(r'\n','  ',texto_limpio)
texto_limpio = re.sub(r'\*',' ',texto_limpio)
print(texto_limpio)
#speaker.say(texto_limpio)
#speaker.runAndWait()
# Out:
# [    También se sintió en otros del centro como    [Cundinamarc] a  ,  Quindío, Tolima, Risaralda, Meta, Guaviare, Boyacá y Caldas.    ,    Las autoridades colombianas no han informado de víctimas o daños materiales y  siguen haciendo un barrido por el país para tener un   balance detallado   de  posibles afectaciones.    ,    "Expresamos toda nuestra solidaridad al hermano pueblo del Perú por el   sismo  de 7,5   que sacudió al país esta madrugada y que tuvo como epicentro la  región amazónica. Estamos atentos a los reportes sobre afectaciones para  coordinar la ayuda que podamos prestar desde  [  Colombia  ] ", escribió  el jefe de Estado    ,    En   Ecuador   , el   Sistema Nacional de Gestión de Riesgos y Emergencias    informó que edificaciones del sur del país sufrieron daños por el terremoto  que hasta el momento no deja víctimas humanas.    ,    Expresamos toda nuestra solidaridad al hermano pueblo del  [#Perú]   por el sismo de 7.5° que sacudió al país esta madrugada y que tuvo como  epicentro la región amazónica. Estamos atentos a los reportes sobre  afectaciones para coordinar la ayuda que podamos prestar desde Colombia.    ,    ['La muerte de Dios', el documental sobre los excesos de Diego  Maradona]     ,    [Mi Banda Sonora con Ubaldina  Valoyes]     ,    [Mompox, tierra de artesanías, cultura y  turismo]     ,    Copiar    ]

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")

# %%
from sentence_utils import split_into_sentences
frase = split_into_sentences(texto_limpio)
frase
# Out:
# ['[    También se sintió en otros del centro como    [Cundinamarc] a  ,  Quindío, Tolima, Risaralda, Meta, Guaviare, Boyacá y Caldas.',
#  ',    Las autoridades colombianas no han informado de víctimas o daños materiales y  siguen haciendo un barrido por el país para tener un   balance detallado   de  posibles afectaciones.',
#  ',    "Expresamos toda nuestra solidaridad al hermano pueblo del Perú por el   sismo  de 7,5   que sacudió al país esta madrugada y que tuvo como epicentro la  región amazónica.',
#  'Estamos atentos a los reportes sobre afectaciones para  coordinar la ayuda que podamos prestar desde  [  Colombia  ] ", escribió  el jefe de Estado    ,    En   Ecuador   , el   Sistema Nacional de Gestión de Riesgos y Emergencias    informó que edificaciones del sur del país sufrieron daños por el terremoto  que hasta el momento no deja víctimas humanas.',
#  ',    Expresamos toda nuestra solidaridad al hermano pueblo del  [#Perú]   por el sismo de 7.',
#  '5° que sacudió al país esta madrugada y que tuvo como  epicentro la región amazónica.',
#  'Estamos atentos a los reportes sobre  afectaciones para coordinar la ayuda que podamos prestar desde Colombia.',
#  ",    ['La muerte de Dios', el documental sobre los excesos de Diego  Maradona]     ,    [Mi Banda Sonora con Ubaldina  Valoyes]     ,    [Mompox, tierra de artesanías, cultura y  turismo]     ,    Copiar    ]"]

# %%
sentence = translator(frase)

# %%
sentence
# Out:
# [{'translation_text': '[ It was also felt in others of the center like [Cundinamarc] to , Quindío, Tolima, Risaralda, Meta, Guaviare, Boyacá and Caldas.'},
#  {'translation_text': 'The Colombian authorities have not reported any casualties or material damage and continue to sweep the country in order to have a detailed account of possible impacts.'},
#  {'translation_text': '"We express all our solidarity to the brotherly people of Peru for the earthquake of 7.5 that shook the country this morning and had the Amazon region as its epicenter.'},
#  {'translation_text': 'We are attentive to reports on impacts to coordinate the assistance we can provide from [Colombia] ", wrote the head of state , In Ecuador , the National System of Risk and Emergency Management reported that buildings in the south of the country suffered damage from the earthquake that so far leaves no human victims.'},
#  {'translation_text': ', We express all our solidarity to the brotherly people of [#Peru] for the earthquake of 7.'},
#  {'translation_text': '5th that shook the country this morning and had the Amazon region as its epicenter.'},
#  {'translation_text': 'We are attentive to reports on impacts to coordinate the assistance we can provide from Colombia.'},
#  {'translation_text': ", ['The Death of God', the documentary about Diego Maradona's excesses] , [My Sonora Band with Ubaldina Valoyes] , [Mompox, land of crafts, culture and tourism] , Copy ]"}]

# %%
todo_texto = [sentences['translation_text'] for sentences in sentence]
todo_texto = ' '.join(todo_texto)
todo_texto
# Out:
# '[ It was also felt in others of the center like [Cundinamarc] to , Quindío, Tolima, Risaralda, Meta, Guaviare, Boyacá and Caldas. The Colombian authorities have not reported any casualties or material damage and continue to sweep the country in order to have a detailed account of possible impacts. "We express all our solidarity to the brotherly people of Peru for the earthquake of 7.5 that shook the country this morning and had the Amazon region as its epicenter. We are attentive to reports on impacts to coordinate the assistance we can provide from [Colombia] ", wrote the head of state , In Ecuador , the National System of Risk and Emergency Management reported that buildings in the south of the country suffered damage from the earthquake that so far leaves no human victims. , We express all our solidarity to the brotherly people of [#Peru] for the earthquake of 7. 5th that shook the country this morning and had the Amazon region as its epicenter. We are attentive to reports on impacts to coordinate the assistance we can provide from Colombia. , [\'The Death of God\', the documentary about Diego Maradona\'s excesses] , [My Sonora Band with Ubaldina Valoyes] , [Mompox, land of crafts, culture and tourism] , Copy ]'

# %%
summarizer = pipeline("summarization")

# %%
resumen = summarizer(todo_texto)

# %%
resumen_en = resumen[0]['summary_text']
resumen_en
# Out:
# " Colombian authorities have not reported any casualties or material damage from the 7.5 earthquake that shook the country this morning and had the Amazon region as its epicenter . Colombia's head of state expresses solidarity to the brotherly people of Peru for the earthquake . Ecuador's National System of Risk and Emergency Management reported that buildings in the south of the country suffered damage ."

# %%
summarizer = pipeline("summarization")

# %%
resumen = summarizer(todo_texto)

# %%
resumen_en = resumen[0]['summary_text']
resumen_en
# Out:
# " Colombian authorities have not reported any casualties or material damage from the 7.5 earthquake that shook the country this morning and had the Amazon region as its epicenter . Colombia's head of state expresses solidarity to the brotherly people of Peru for the earthquake . Ecuador's National System of Risk and Emergency Management reported that buildings in the south of the country suffered damage ."

# %%
translator_en_es = pipeline("translation", model="Helsinki-NLP/opus-mt-en-es")

# %%
resumen_es_list = translator_en_es(resumen_en)

# %%
resumen_es = resumen_es_list[0]['translation_text']
resumen_es
# Out:
# 'Las autoridades colombianas no han reportado víctimas ni daños materiales por el terremoto de 7.5 que sacudió al país esta mañana y tuvo a la región amazónica como su epicentro . El jefe de Estado de Colombia expresa su solidaridad con el hermano pueblo de Perú por el terremoto . El Sistema Nacional de Gestión de Riesgos y Emergencias de Ecuador informó que los edificios en el sur del país sufrieron daños .'

# %%
speaker.say(resumen_es)
speaker.runAndWait()

# %%
noticias_encabezados = [noticia['title'] for noticia in noticias]
noticias_encabezados = [re.sub(' -\s.*\S$','',noticias_encabezado) for noticias_encabezado in noticias_encabezados]
noticias_encabezados
# Out:
# ['Se presentó y se firmó el decreto de la Ley del Vigilante',
#  'Ojo con estas 13 aplicaciones populares en celulares Android que roban información valiosa',
#  'Conozca los mejores trucos de WhatsApp en su nueva actualización',
#  'WhatsApp vuelve con sus condiciones a usuarios y habría nueva fecha límite para aceptarlas',
#  'Que no lo tumben: las claves para identificar si un negocio de criptomonedas es real o no']

# %%
# !python -m spacy download es_core_news_lg

# %%
nlp = spacy.load('es_core_news_lg')

# %%
texto_comparar = nlp('policia')

[nlp(encabezado).similarity(texto_comparar) for encabezado in noticias_encabezados]
# Out:
# [0.12374630824919926,
#  0.3852905161744063,
#  0.08033732324755001,
#  0.23713419326636698,
#  -0.10259521986963996]

# %%
try:
    with speech_recognition.Microphone() as mic:
        recognizer.adjust_for_ambient_noise(mic,duration=0.2)
        audio=recognizer.listen(mic)
        texto=recognizer.recognize_google(audio,language="es-CO")#item
        similitud = [nlp(encabezado).similarity(nlp(texto)) for encabezado in noticias_encabezados]
        cual_not = noticias_encabezados[np.argmax(np.array(similitud))]
    
except speech_recognition.UnknownValueError:
    recognizer=speech_recognition.Recognizer()
    speaker.say("No entendi lo que dijiste, por favor podrias repetir?")
    speaker.runAndWait()

print(cual_not)
print(texto)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d_/hfs18jf54371qfmf54zq289c0000gn/T/ipykernel_3325/2757660191.py in <module>
#       4         audio=recognizer.listen(mic)
#       5         texto=recognizer.recognize_google(audio,language="es-CO")#item
# ----> 6         similitud = [nlp(encabezado).similarity(nlp(texto)) for encabezado in noticias_encabezados]
#       7         cual_not = noticias_encabezados[np.argmax(np.array(similitud))]
#       8
#
# NameError: name 'noticias_encabezados' is not defined

# %% [markdown]
# ## Librerías Necesarias

# %%
# Abrir conexiones de una página web
import requests
# Bella sopa de muchas cosas de HTML
from bs4 import BeautifulSoup
# Expresiones regulares para filtrar dentro de la sopa
import re
# Transformar html a texto
import html2text
# Separar texto en frases (Para el transformer)
from sentence_utils import split_into_sentences
# Utilidad de resumen y traducción
from transformers import pipeline
# Conexión con Google News
from gnewsclient import gnewsclient
# Manejo de vectores
import numpy as np

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ##  Extraer Noticias de Google News

# %% [markdown]
# Es posible extraer noticias asociadas a [Google News](https://news.google.com/), usando la herramienta [`gnewsclient`](https://pypi.org/project/gnewsclient/), desarrollada por Nikhil Kumar Singh.
#
# Es una herramienta bastante intuitiva de usar.
#
# Considere que haremos un **Web Scraping** de una página que hace Web Scraping de noticias, utilizando los motores de Google.

# %%
# Inicializar el objeto gnewsclient
client = gnewsclient.NewsClient()

# %% [markdown]
# Como observamos a continuación, el cliente tiene algunas propiedades y métodos útiles:

# %%
print(dir(client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'get_config', 'get_news', 'language', 'languages', 'location', 'locations', 'max_results', 'params_dict', 'parse_feed', 'topic', 'topics', 'use_opengraph']

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ## Propiedades del Cliente de Noticias

# %% [markdown]
# Podemos observar que tenemos varios países a disposición:

# %%
print(client.locations)
# Out:
# ['Australia', 'Botswana', 'Canada ', 'Ethiopia', 'Ghana', 'India ', 'Indonesia', 'Ireland', 'Israel ', 'Kenya', 'Latvia', 'Malaysia', 'Namibia', 'New Zealand', 'Nigeria', 'Pakistan', 'Philippines', 'Singapore', 'South Africa', 'Tanzania', 'Uganda', 'United Kingdom', 'United States', 'Zimbabwe', 'Czech Republic', 'Germany', 'Austria', 'Switzerland', 'Argentina', 'Chile', 'Colombia', 'Cuba', 'Mexico', 'Peru', 'Venezuela', 'Belgium ', 'France', 'Morocco', 'Senegal', 'Italy', 'Lithuania', 'Hungary', 'Netherlands', 'Norway', 'Poland', 'Brazil', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Sweden', 'Vietnam', 'Turkey', 'Greece', 'Bulgaria', 'Russia', 'Ukraine ', 'Serbia', 'United Arab Emirates', 'Saudi Arabia', 'Lebanon', 'Egypt', 'Bangladesh', 'Thailand', 'China', 'Taiwan', 'Hong Kong', 'Japan', 'Republic of Korea']

# %%
print(f'Países Disponibles: {len(client.locations)}')
# Out:
# Países Disponibles: 69

# %% [markdown]
# Además, podemos minar en diferentes idiomas también:

# %%
print(client.languages)
# Out:
# ['english', 'indonesian', 'czech', 'german', 'spanish', 'french', 'italian', 'latvian', 'lithuanian', 'hungarian', 'dutch', 'norwegian', 'polish', 'portuguese brasil', 'portuguese portugal', 'romanian', 'slovak', 'slovenian', 'swedish', 'vietnamese', 'turkish', 'greek', 'bulgarian', 'russian', 'serbian', 'ukrainian', 'hebrew', 'arabic', 'marathi', 'hindi', 'bengali', 'tamil', 'telugu', 'malyalam', 'thai', 'chinese simplified', 'chinese traditional', 'japanese', 'korean']

# %%
print(f'Idiomas Disponibles: {len(client.languages)}')
# Out:
# Idiomas Disponibles: 39

# %% [markdown]
# Podemos también elegir entre diferentes temas disponibles:

# %%
# Mostrar Tópicos disponibles
topicos = client.topics
print(topicos)
# Out:
# ['Top Stories', 'World', 'Nation', 'Business', 'Technology', 'Entertainment', 'Sports', 'Science', 'Health']

# %% [markdown]
# Tal vez, el método más importante de este paquete es **`get_news()`**, que busca por las noticias solicitadas en la web a través de Google.

# %%
# Obtener las noticias del cliente
noticias = client.get_news()
noticias
# Out:
# [{'title': "Kentucky governor confirms 64 dead after devastating weekend tornadoes: 'Undoubtedly there will be more' - USA TODAY",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiggFodHRwczovL3d3dy51c2F0b2RheS5jb20vc3RvcnkvbmV3cy9uYXRpb24vMjAyMS8xMi8xMy9rZW50dWNreS10b3JuYWRvLWRlYXRoLXRvbGwtY2xpbWJzLXNlYXJjaC1jb250aW51ZXMtd2hhdC13ZS1rbm93LzY0OTE1OTMwMDEv0gEA?oc=5',
#   'media': None},
#  {'title': 'Tornado outbreak offers a grim climate warning - Axios',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMicGh0dHBzOi8vd3d3LmF4aW9zLmNvbS90b3JuYWRvLWRpc2FzdGVyLWtlbnR1Y2t5LWNsaW1hdGUtY2hhbmdlLXdhcm5pbmctYTRjMjc4OGMtNDZmZC00ODUxLWE1NWYtZTM3Mzc5ODgxNGY5Lmh0bWzSAQA?oc=5',
#   'media': None},
#  {'title': 'Chris Wallace leaving Fox News after 18 years for new CNN streaming service - CBS News',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiPWh0dHBzOi8vd3d3LmNic25ld3MuY29tL25ld3MvY2hyaXMtd2FsbGFjZS1mb3gtbmV3cy1jbm4tcGx1cy_SAQA?oc=5',
#   'media': None},
#  {'title': 'Workers killed in Edwardsville building collapse include mother of toddler, Army veteran - STLtoday.com',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'Some Hospitals Drop Covid-19 Vaccine Mandates to Ease Labor Shortages - The Wall Street Journal',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMibmh0dHBzOi8vd3d3Lndzai5jb20vYXJ0aWNsZXMvc29tZS1ob3NwaXRhbHMtZHJvcC1jb3ZpZC0xOS12YWNjaW5lLW1hbmRhdGVzLXRvLWVhc2UtbGFib3Itc2hvcnRhZ2VzLTExNjM5Mzk2ODA20gEA?oc=5',
#   'media': None},
#  {'title': "Meadows said National Guard would be ready to 'protect pro Trump people' before Capitol insurrection, House investigators say - CNN",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMicWh0dHBzOi8vd3d3LmNubi5jb20vMjAyMS8xMi8xMi9wb2xpdGljcy9tYXJrLW1lYWRvd3MtamFudWFyeS1jb21taXR0ZWUtY29udGVtcHQtb2YtY29uZ3Jlc3MtcmVzb2x1dGlvbi9pbmRleC5odG1s0gEA?oc=5',
#   'media': None},
#  {'title': 'Search halted for woman who fell overboard from Carnival cruise ship - NBC News',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiZWh0dHBzOi8vd3d3Lm5iY25ld3MuY29tL25ld3MvdXMtbmV3cy9zZWFyY2gtaGFsdGVkLXdvbWFuLWZlbGwtb3ZlcmJvYXJkLWNhcm5pdmFsLWNydWlzZS1zaGlwLXJjbmE4NTQx0gEpaHR0cHM6Ly93d3cubmJjbmV3cy5jb20vbmV3cy9hbXAvcmNuYTg1NDE?oc=5',
#   'media': None},
#  {'title': "December's child tax credit payment will be the last one unless Congress acts - CNN",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiVGh0dHBzOi8vd3d3LmNubi5jb20vMjAyMS8xMi8xMy9wb2xpdGljcy9kZWNlbWJlci1jaGlsZC10YXgtY3JlZGl0LXBheW1lbnQvaW5kZXguaHRtbNIBAA?oc=5',
#   'media': None},
#  {'title': "UK reports first known death from omicron; Fauci says boosters offer 'optimal' protection against variant: COVID-19 updates - USA TODAY",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMibWh0dHBzOi8vd3d3LnVzYXRvZGF5LmNvbS9zdG9yeS9uZXdzL2hlYWx0aC8yMDIxLzEyLzEzL3ZhY2NpbmUtYm9vc3Rlci1vbWljcm9uLWNhc2VzLWNvdmlkLXVwZGF0ZXMvNjQ4NzM2MjAwMS_SAQA?oc=5',
#   'media': None},
#  {'title': 'Deadly Baytown drive-by shooting: 1 dead, 13 people injured at candlelight vigil, Harris County Sheriff Ed Gonzalez says - KTRK-TV',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None}]

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ## Fijar parámetros del Cliente

# %% [markdown]
# Podemos elegir entre tópicos de a lista y pasarlos al cliente:

# %%
print(topicos)
# Out:
# ['Top Stories', 'World', 'Nation', 'Business', 'Technology', 'Entertainment', 'Sports', 'Science', 'Health']

# %%
# Elegir de tópicos discponibles
client.topic = topicos[-1]

# %%
print(client.languages)
# Out:
# ['english', 'indonesian', 'czech', 'german', 'spanish', 'french', 'italian', 'latvian', 'lithuanian', 'hungarian', 'dutch', 'norwegian', 'polish', 'portuguese brasil', 'portuguese portugal', 'romanian', 'slovak', 'slovenian', 'swedish', 'vietnamese', 'turkish', 'greek', 'bulgarian', 'russian', 'serbian', 'ukrainian', 'hebrew', 'arabic', 'marathi', 'hindi', 'bengali', 'tamil', 'telugu', 'malyalam', 'thai', 'chinese simplified', 'chinese traditional', 'japanese', 'korean']

# %% [markdown]
# Podemos también elegir el idioma de nuestro interés:

# %%
client.language = 'greek'

# %%
client.get_news()
# Out:
# [{'title': 'Στάθης Παναγιωτόπουλος: Σοκάρουν οι αποκαλύψεις - Απέκρυψε το δικαστήριο για υπόθεση «revenge porn» - Κατακραυγή στο Twitter - Πρώτο Θέμα',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': '«Θεματοφύλακες του Συντάγματος» – «Ο γυμνασιάρχης ξεκίνησε τους προπηλακισμούς» λένε στην απολογία τους - in.gr',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiiAFodHRwczovL3d3dy5pbi5nci8yMDIxLzEyLzEzL2dyZWVjZS90aGVtYXRvZnlsYWtlcy10b3Utc3ludGFnbWF0b3Mtby1neW1uYXNpYXJ4aXMta3Nla2luaXNlLXRvdXMtcHJvcGlsYWtpc21vdXMtbGVuZS1zdGluLWFwb2xvZ2lhLXRvdXMv0gEA?oc=5',
#   'media': None},
#  {'title': 'Ρέθυμνο: Πήγε να κάνει απογραφή και έπεσε θύμα σεξουαλικής παρενόχλησης - iefimerida',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiVmh0dHBzOi8vd3d3LmllZmltZXJpZGEuZ3IvZWxsYWRhL3JldGh5bW5vLWFwb2dyYWZlYXMta2F0aWdnZWlsZS1uZWFyby1hc2VsZ2Vpcy1wcmF4ZWlz0gEA?oc=5',
#   'media': None},
#  {'title': 'Επανέρχονται από την Τρίτη τα δρομολόγια Προαστιακού που είχαν ανασταλεί λόγω εργασιών - Zougla',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMieGh0dHBzOi8vd3d3LnpvdWdsYS5nci9ncmVlY2UvYXJ0aWNsZS9lcGFuZXJ4b250ZS1hcG8tdGluLXRyaXRpLXRhLWRyb21vbG9naWEtcHJvYXN0aWFrb3UtcG91LWl4YW4tYW5hc3RhbGktbG9nby1lcmdhc2lvbtIBAA?oc=5',
#   'media': None}]

# %% [markdown]
# También es posible iniciar el cliente con parámetros fijos desde el principio:

# %%
# Con opengraph se puede filtrar el medio de comunicación
client = gnewsclient.NewsClient(location='Colombia', language='spanish', topic='Nation', use_opengraph=True, max_results=10)
# Obtener noticias
noticias = client.get_news()

# %%
print(np.random.choice(noticias))
# Out:
# {'url': 'https://www.semana.com/nacion/articulo/soy-un-limosnero-en-bogota-rodolfo-hernandez-hablo-sobre-su-supuesta-fortuna/202127/', 'site_name': 'Semana.com   Últimas Noticias de Colombia y el Mundo', 'title': '“Soy un limosnero en Bogotá”: Rodolfo Hernández habló sobre su supuesta fortuna - Revista Semana', 'description': 'El exalcalde de Bucaramanga y aspirante presidencial aseguró que paga 7.000 millones de pesos al año en impuestos.', 'image': 'https://www.semana.com/resizer/CZauAqe-3Xk3vIyJNRAl_Hyxm-w=/1200x646/filters:format(jpg):quality(50)/cloudfront-us-east-1.images.arcpublishing.com/semana/XSARODN3O5GKRLXK537DMCMX44.JPG', 'type': 'article', 'locale': 'es_LA', 'image:secure_url': 'https://www.semana.com/resizer/CZauAqe-3Xk3vIyJNRAl_Hyxm-w=/1200x646/filters:format(jpg):quality(50)/cloudfront-us-east-1.images.arcpublishing.com/semana/XSARODN3O5GKRLXK537DMCMX44.JPG', 'image_width': 150, 'image_height': 80.75, 'link': 'https://news.google.com/__i/rss/rd/articles/CBMie2h0dHBzOi8vd3d3LnNlbWFuYS5jb20vbmFjaW9uL2FydGljdWxvL3NveS11bi1saW1vc25lcm8tZW4tYm9nb3RhLXJvZG9sZm8taGVybmFuZGV6LWhhYmxvLXNvYnJlLXN1LXN1cHVlc3RhLWZvcnR1bmEvMjAyMTI3L9IBAA?oc=5', 'media': None}

# %% [markdown]
# Note que el uso de **openGraph** nos permite obtener más características de las noticias, tales como imágenes asociadas, descripciones y tipo de noticia.

# %%
print(noticias[0].keys())
# Out:
# dict_keys(['url', 'site_name', 'title', 'description', 'image', 'type', 'locale', 'image:secure_url', 'image_width', 'image_height', 'link', 'media'])

# %%
#Mostrar noticias
for noticia in noticias:
    print(noticia['site_name'],noticia['title'],noticia['url'],noticia['link'],sep='\n',end='\n\n')
# Out:
# Semana.com   Últimas Noticias de Colombia y el Mundo
# Atención: centrales sindicales del país proponen este incremento en el salario mínimo para 2022 - Revista Semana
# https://www.semana.com/economia/macroeconomia/articulo/atencion-centrales-sindicales-del-pais-proponen-este-incremento-en-el-salario-minimo-para-2022/202155/
# https://news.google.com/__i/rss/rd/articles/CBMinQFodHRwczovL3d3dy5zZW1hbmEuY29tL2Vjb25vbWlhL21hY3JvZWNvbm9taWEvYXJ0aWN1bG8vYXRlbmNpb24tY2VudHJhbGVzLXNpbmRpY2FsZXMtZGVsLXBhaXMtcHJvcG9uZW4tZXN0ZS1pbmNyZW1lbnRvLWVuLWVsLXNhbGFyaW8tbWluaW1vLXBhcmEtMjAyMi8yMDIxNTUv0gEA?oc=5
#
# www.elcolombiano.com
# Hay acuerdo para subir el salario mínimo a un millón: Mintrabajo - El Colombiano
# https://www.elcolombiano.com/negocios/salario-minimo-de-2022-en-un-millon-en-colombia-tiene-aval-de-gobierno-empresas-y-centrales-obreras-BC16147969
# https://news.google.com/__i/rss/rd/articles/CBMilAFodHRwczovL3d3dy5lbGNvbG9tYmlhbm8uY29tL25lZ29jaW9zL3NhbGFyaW8tbWluaW1vLWRlLTIwMjItZW4tdW4tbWlsbG9uLWVuLWNvbG9tYmlhLXRpZW5lLWF2YWwtZGUtZ29iaWVybm8tZW1wcmVzYXMteS1jZW50cmFsZXMtb2JyZXJhcy1CQzE2MTQ3OTY50gEA?oc=5
#
# El País
# Una investigación de la ONU concluye que la policía colombiana mató a 11 jóvenes en las protestas de Bogotá - EL PAÍS
# https://elpais.com/internacional/2021-12-13/una-investigacion-de-la-onu-concluye-que-la-policia-colombiana-mato-a-11-jovenes-en-las-protestas-de-bogota.html
# https://news.google.com/__i/rss/rd/articles/CBMinAFodHRwczovL2VscGFpcy5jb20vaW50ZXJuYWNpb25hbC8yMDIxLTEyLTEzL3VuYS1pbnZlc3RpZ2FjaW9uLWRlLWxhLW9udS1jb25jbHV5ZS1xdWUtbGEtcG9saWNpYS1jb2xvbWJpYW5hLW1hdG8tYS0xMS1qb3ZlbmVzLWVuLWxhcy1wcm90ZXN0YXMtZGUtYm9nb3RhLmh0bWzSAQA?oc=5
#
# EL HERALDO
# Desde este martes exigirán esquema completo de vacunación en sitios públicos - EL HERALDO
# https://www.elheraldo.co/colombia/desde-este-martes-exigiran-esquema-completo-de-vacunacion-en-sitios-publicos-872855
# https://news.google.com/__i/rss/rd/articles/CBMidWh0dHBzOi8vd3d3LmVsaGVyYWxkby5jby9jb2xvbWJpYS9kZXNkZS1lc3RlLW1hcnRlcy1leGlnaXJhbi1lc3F1ZW1hLWNvbXBsZXRvLWRlLXZhY3VuYWNpb24tZW4tc2l0aW9zLXB1YmxpY29zLTg3Mjg1NdIBAA?oc=5
#
# pulzo.com
# Colombia tuvo notables aumentos de contagios diarios y de casos activos por COVID-19 - Pulzo
# https://www.pulzo.com/nacion/coronavirus-colombia-nuevos-casos-muertes-12-diciembre-2021-noticias-hoy-PP1107414
# https://news.google.com/__?oc=5
#
# El Tiempo
# Mabel Lara encabezará la lista del Senado del Nuevo Liberalismo - El Tiempo
# https://www.eltiempo.com/politica/partidos-politicos/mabel-lara-sera-cabeza-de-lista-del-nuevo-liberalismo-638679
# https://news.google.com/__i/rss/rd/articles/CBMicWh0dHBzOi8vd3d3LmVsdGllbXBvLmNvbS9wb2xpdGljYS9wYXJ0aWRvcy1wb2xpdGljb3MvbWFiZWwtbGFyYS1zZXJhLWNhYmV6YS1kZS1saXN0YS1kZWwtbnVldm8tbGliZXJhbGlzbW8tNjM4Njc50gEA?oc=5
#
# Bogota.gov.co
# Puntos de vacunación contra COVID-19 en Bogotá. Lunes 13 de diciembre | Bogota.gov.co - Portal de Bogotá
# https://bogota.gov.co/mi-ciudad/salud/puntos-de-vacunacion-contra-covid-19-en-bogota-lunes-13-de-diciembre
# https://news.google.com/__i/rss/rd/articles/CBMiamh0dHBzOi8vYm9nb3RhLmdvdi5jby9taS1jaXVkYWQvc2FsdWQvcHVudG9zLWRlLXZhY3VuYWNpb24tY29udHJhLWNvdmlkLTE5LWVuLWJvZ290YS1sdW5lcy0xMy1kZS1kaWNpZW1icmXSAQA?oc=5
#
# ELESPECTADOR.COM
# Fernando Sanclemente: imputado porque habría quemado pruebas del caso narcofinca - El Espectador
# https://www.elespectador.com/judicial/fernando-sanclemente-habria-quemado-pruebas-del-caso-narcofinca-fiscalia/
# https://news.google.com/__i/rss/rd/articles/CBMib2h0dHBzOi8vd3d3LmVsZXNwZWN0YWRvci5jb20vanVkaWNpYWwvZmVybmFuZG8tc2FuY2xlbWVudGUtaGFicmlhLXF1ZW1hZG8tcHJ1ZWJhcy1kZWwtY2Fzby1uYXJjb2ZpbmNhLWZpc2NhbGlhL9IBAA?oc=5
#
# Semana.com   Últimas Noticias de Colombia y el Mundo
# “Soy un limosnero en Bogotá”: Rodolfo Hernández habló sobre su supuesta fortuna - Revista Semana
# https://www.semana.com/nacion/articulo/soy-un-limosnero-en-bogota-rodolfo-hernandez-hablo-sobre-su-supuesta-fortuna/202127/
# https://news.google.com/__i/rss/rd/articles/CBMie2h0dHBzOi8vd3d3LnNlbWFuYS5jb20vbmFjaW9uL2FydGljdWxvL3NveS11bi1saW1vc25lcm8tZW4tYm9nb3RhLXJvZG9sZm8taGVybmFuZGV6LWhhYmxvLXNvYnJlLXN1LXN1cHVlc3RhLWZvcnR1bmEvMjAyMTI3L9IBAA?oc=5
#
# www.elcolombiano.com
# Transportadores levantaron paro en Rionegro - El Colombiano
# https://www.elcolombiano.com/antioquia/levantan-paro-de-transportes-en-rionegro-tras-acuerdo-con-alcalde-rodrigo-hernandez-BC16146777
# https://news.google.com/__?oc=5

# %% [markdown]
# **Observaciones:** No siempre `site_name=None` implica que no se pueda acceder a la noticia:
#
# **Ejemplo:**
#
# [Lo peor de ómicron, hasta ahora, es la incertidumbre - Yahoo Finanzas](https://news.google.com/__?oc=5)

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ## Scrapy de Noticias

# %% [markdown]
# ### Estado de Conexión

# %% [markdown]
# Podemos usar la librería `requests` para generar una conexión hacia la página web de la cual queremos extraer la información:

# %%
# Elegir noticia al azar
noticia_elegida = np.random.choice(noticias)
# Obtener info importante del diccionario de gnews
medio = noticia_elegida['site_name']
# nombre del sitio de la noticia
titular = noticia_elegida['title']
# url de la noticia elegida
url = noticia_elegida['url']
# Elegir link adecuado, a veces url=None
if url==None or re.search('http',url)==None:
    # Si no hay info, ir desde Google
    url = noticia_elegida['link']
# Imprimir info importante
print(medio,titular,url,sep='\n\n',end='\n\n')
# Rompe defensa dummy anti-robot: https://stackoverflow.com/questions/38489386/python-requests-403-forbidden
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
# Obtener info de la página web
res = requests.get(url,headers=headers)
# Mostrar estado de la conexión
print("Estado de conexión:", res.status_code,res.reason, "(200 = OK, 403 = NOT OK)")
# Out:
# El Tiempo
#
# Mabel Lara encabezará la lista del Senado del Nuevo Liberalismo - El Tiempo
#
# https://www.eltiempo.com/politica/partidos-politicos/mabel-lara-sera-cabeza-de-lista-del-nuevo-liberalismo-638679
#
# Estado de conexión: 200 OK (200 = OK, 403 = NOT OK)

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ### Beautiful Soup

# %% [markdown]
# En caso de tener conexión, `requests.content` copiará **todo** en contenido encontrado en la página fuente:

# %%
# Obtener contenido Web
html_page = res.content
# Mostrar algo de código fuente
print(html_page[:2000])
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<script async type=\'text/javascript\'>var _sf_startpt=(new Date()).getTime()</script>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<script type="text/javascript">\nwindow.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){j+'

# %% [markdown]
# Para poder decodificar símbolos especiales y organizar en forma coherente para python, usaremos la librería `BeautifulSoup`:

# %%
## Obtener la sopa del HTML (construye la estructura de datos para poder minar por tags)
soup = BeautifulSoup(html_page, 'html.parser')
# parser permite decodificar algunos símbolos
print(soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" type="text/javascript">
#    var _sf_startpt=(new Date()).getTime()
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e

# %% [markdown]
# Notemos que BeautifulSoup tiene bastantes herramientas para trabajar:

# %%
print(dir(soup))
# Out:
# ['ASCII_SPACES', 'DEFAULT_BUILDER_FEATURES', 'DEFAULT_INTERESTING_STRING_TYPES', 'NO_PARSER_SPECIFIED_WARNING', 'ROOT_TAG_NAME', '__bool__', '__call__', '__class__', '__contains__', '__copy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_all_strings', '_check_markup_is_url', '_decode_markup', '_feed', '_find_all', '_find_one', '_is_xml', '_lastRecursiveChild', '_last_descendant', '_linkage_fixer', '_most_recent_element', '_namespaces', '_popToTag', '_should_pretty_print', 'append', 'attrs', 'builder', 'can_be_empty_element', 'cdata_list_attributes', 'childGenerator', 'children', 'clear', 'contains_replacement_characters', 'contents', 'currentTag', 'current_data', 'declared_html_encoding', 'decode', 'decode_contents', 'decompose', 'decomposed', 'default', 'descendants', 'element_classes', 'encode', 'encode_contents', 'endData', 'extend', 'extract', 'fetchNextSiblings', 'fetchParents', 'fetchPrevious', 'fetchPreviousSiblings', 'find', 'findAll', 'findAllNext', 'findAllPrevious', 'findChild', 'findChildren', 'findNext', 'findNextSibling', 'findNextSiblings', 'findParent', 'findParents', 'findPrevious', 'findPreviousSibling', 'findPreviousSiblings', 'find_all', 'find_all_next', 'find_all_previous', 'find_next', 'find_next_sibling', 'find_next_siblings', 'find_parent', 'find_parents', 'find_previous', 'find_previous_sibling', 'find_previous_siblings', 'format_string', 'formatter_for_name', 'get', 'getText', 'get_attribute_list', 'get_text', 'handle_data', 'handle_endtag', 'handle_starttag', 'has_attr', 'has_key', 'hidden', 'index', 'insert', 'insert_after', 'insert_before', 'interesting_string_types', 'isSelfClosing', 'is_empty_element', 'is_xml', 'known_xml', 'markup', 'name', 'namespace', 'new_string', 'new_tag', 'next', 'nextGenerator', 'nextSibling', 'nextSiblingGenerator', 'next_element', 'next_elements', 'next_sibling', 'next_siblings', 'object_was_parsed', 'open_tag_counter', 'original_encoding', 'parent', 'parentGenerator', 'parents', 'parse_only', 'parserClass', 'parser_class', 'popTag', 'prefix', 'preserve_whitespace_tag_stack', 'preserve_whitespace_tags', 'prettify', 'previous', 'previousGenerator', 'previousSibling', 'previousSiblingGenerator', 'previous_element', 'previous_elements', 'previous_sibling', 'previous_siblings', 'pushTag', 'recursiveChildGenerator', 'renderContents', 'replaceWith', 'replaceWithChildren', 'replace_with', 'replace_with_children', 'reset', 'select', 'select_one', 'setup', 'smooth', 'string', 'string_container', 'string_container_stack', 'strings', 'stripped_strings', 'tagStack', 'text', 'unwrap', 'wrap']

# %% [markdown]
# [[Volver al inicio]](#Contenido)

# %% [markdown]
# ### Obtención del texto de la noticia

# %%
# Info Básica
print(medio,titular,url,sep='\n\n',end='\n\n')
# Out:
# El Tiempo
#
# Mabel Lara encabezará la lista del Senado del Nuevo Liberalismo - El Tiempo
#
# https://www.eltiempo.com/politica/partidos-politicos/mabel-lara-sera-cabeza-de-lista-del-nuevo-liberalismo-638679

# %%
texto = soup.find_all('p',{'class': 'contenido'})
texto
# Out:
# [<p class="contenido" id="p638679-m474-473-475">Tal y como lo había anunciado EL TIEMPO desde la semana pasada, la periodista <b>Mábel Lara</b> fue confirmada este lunes como la<b> cabeza de lista del Senado </b>por el revivido partido político <b>Nuevo Liberalismo. </b><br/><br/>"<i>#1 Una mujer negra, del Pacífico colombiano. Defensora de la libre empresa, libertad de expresión y opinión, derecho a las mujeres a decidir sobre su cuerpo y el rechazo a los autoritarismos. Mabel Lara asume la responsabilidad del futuro colombiano</i>", escribió el candidato presidencial de la colectividad, Juan Manuel Galán. <br/><br/>(Lea también: <a href="https://www.eltiempo.com/politica/partidos-politicos/hoy-se-conoceran-las-cartas-definitivas-en-las-listas-al-congreso-638551" target="_blank">Este lunes se conocerán las cartas definitivas en las listas al Congreso). </a></p>,
#  <p class="contenido" id="p638679-m524-3-525">Además del estreno en la política de la columnista y presentadora, la lista del partido fundado por <b>Luis Carlos Galán</b>  está llena de sorpresas. <br/><br/>Una de las más grandes incógnitas era si Carlos Fernando Galán, quien renunció el viernes al Concejo de Bogotá se iba o no a lanzar al Congreso.  La respuesta es sí: va a ir con el número 6.</p>,
#  <p class="contenido" id="p638679-m717-4-718"><br/>"#6 Mi hermano, sí. Coherente, valiente, fiel y leal a los principios fundadores del Nuevo Liberalismo. Un líder al servicio del interés colectivo por encima del individual. Carlos Fernando Galán  padre de Julieta y de Juan Pablo, mi ahijado, padrino de mi hijo Manuel", escribió Juan Manuel en su cuenta de Twitter. <br/><br/>(Le puede interesar: <a href="https://www.eltiempo.com/politica/congreso/horas-cruciales-en-la-conformacion-de-listas-al-congreso-638426" target="_blank">Horas cruciales en la conformación de listas al Congreso). </a></p>,
#  <p class="contenido" id="p638679-m554-5-555">Las 4 posiciones previas serán ocupadas por el exdefensor del pueblo, Carlos Negret, quien además fue el secretario general del Partido de La U; la politóloga, columnista y docente,<b> Sandra Borda</b>; el abogado, comunicador social y consultor, Guillermo Pérez Flórez; y la defensora de DD.HH. e integrante de la Mesa Nacional de Víctimas, Yolanda Perea.<br/><br/>(Además: <a href="https://www.eltiempo.com/politica/partidos-politicos/de-la-calle-acepta-encabezar-lista-de-la-coalicion-centro-esperanza-638219" target="_blank">De la Calle acepta encabezar lista de la Coalición Centro Esperanza</a>). <br/><br/>En su columna habitual de los fines de semana, Juan Manuel Galán había asegurado que quienes forman parte de sus listas al Congreso “son un conjunto de obreros de la democracia que se mantienen fieles a los valores liberales y de justicia social” y que los ciudadanos que presentaron sus nombres para ser candidatos “tienen las cualidades y condiciones para servir a un pueblo que exige un Congreso renovado”.<br/><br/>Este lunes dijo que cada uno de los 15 candidatos a la lista del <b>Senado </b>del Nuevo Liberalismo "se han comprometido con 10 causas claras con la urgencia de corregir las injusticias sociales y económicas en Colombia".<br/><br/>(Siga leyendo: <a href="https://www.eltiempo.com/politica/partidos-politicos/exprecandidatos-presidenciales-del-cd-estaran-en-la-lista-al-senado-638362" target="_blank">Exprecandidatos presidenciales del CD estarán en la lista al Senado). <br/></a><br/>POLÍTICA </p>]

# %% [raw]
# # Para italia, il mattino
# texto = soup.find_all('script',{'type':'application/ld+json'})
# # Encontrar dentro del script la parte de , "content":"...
# p=re.compile('([^,\"*]*\w+\s[^\"]*\.)')
# # Encontrar texto escondido
# texto= p.findall(''.join(str(texto)))
# texto

# %% [markdown]
# Librería `html2text`

# %%
# Convertit HTML a Texto    
texto_limpio = html2text.html2text(''.join(str(texto)))
texto_limpio
# Out:
# '[\n\nTal y como lo había anunciado EL TIEMPO desde la semana pasada, la periodista\n**Mábel Lara** fue confirmada este lunes como la **cabeza de lista del\nSenado** por el revivido partido político **Nuevo Liberalismo.**  \n  \n" _#1 Una mujer negra, del Pacífico colombiano. Defensora de la libre empresa,\nlibertad de expresión y opinión, derecho a las mujeres a decidir sobre su\ncuerpo y el rechazo a los autoritarismos. Mabel Lara asume la responsabilidad\ndel futuro colombiano_ ", escribió el candidato presidencial de la\ncolectividad, Juan Manuel Galán.  \n  \n(Lea también: [Este lunes se conocerán las cartas definitivas en las listas al\nCongreso). ](https://www.eltiempo.com/politica/partidos-politicos/hoy-se-\nconoceran-las-cartas-definitivas-en-las-listas-al-congreso-638551)\n\n,\n\nAdemás del estreno en la política de la columnista y presentadora, la lista\ndel partido fundado por **Luis Carlos Galán** está llena de sorpresas.  \n  \nUna de las más grandes incógnitas era si Carlos Fernando Galán, quien renunció\nel viernes al Concejo de Bogotá se iba o no a lanzar al Congreso. La respuesta\nes sí: va a ir con el número 6.\n\n,\n\n  \n"#6 Mi hermano, sí. Coherente, valiente, fiel y leal a los principios\nfundadores del Nuevo Liberalismo. Un líder al servicio del interés colectivo\npor encima del individual. Carlos Fernando Galán padre de Julieta y de Juan\nPablo, mi ahijado, padrino de mi hijo Manuel", escribió Juan Manuel en su\ncuenta de Twitter.  \n  \n(Le puede interesar: [Horas cruciales en la conformación de listas al\nCongreso). ](https://www.eltiempo.com/politica/congreso/horas-cruciales-en-la-\nconformacion-de-listas-al-congreso-638426)\n\n,\n\nLas 4 posiciones previas serán ocupadas por el exdefensor del pueblo, Carlos\nNegret, quien además fue el secretario general del Partido de La U; la\npolitóloga, columnista y docente, **Sandra Borda** ; el abogado, comunicador\nsocial y consultor, Guillermo Pérez Flórez; y la defensora de DD.HH. e\nintegrante de la Mesa Nacional de Víctimas, Yolanda Perea.  \n  \n(Además: [De la Calle acepta encabezar lista de la Coalición Centro\nEsperanza](https://www.eltiempo.com/politica/partidos-politicos/de-la-calle-\nacepta-encabezar-lista-de-la-coalicion-centro-esperanza-638219)).  \n  \nEn su columna habitual de los fines de semana, Juan Manuel Galán había\nasegurado que quienes forman parte de sus listas al Congreso “son un conjunto\nde obreros de la democracia que se mantienen fieles a los valores liberales y\nde justicia social” y que los ciudadanos que presentaron sus nombres para ser\ncandidatos “tienen las cualidades y condiciones para servir a un pueblo que\nexige un Congreso renovado”.  \n  \nEste lunes dijo que cada uno de los 15 candidatos a la lista del **Senado**\ndel Nuevo Liberalismo "se han comprometido con 10 causas claras con la\nurgencia de corregir las injusticias sociales y económicas en Colombia".  \n  \n(Siga leyendo: [Exprecandidatos presidenciales del CD estarán en la lista al\nSenado).  \n](https://www.eltiempo.com/politica/partidos-politicos/exprecandidatos-\npresidenciales-del-cd-estaran-en-la-lista-al-senado-638362)  \nPOLÍTICA\n\n]\n\n'

# %% [markdown]
# ### Limpieza Básica usando expresiones regulares

# %% [markdown]
# Para mayor información, recomendamos visitar [Regular Expressions Cheat Sheet](https://cheatography.com/davechild/cheat-sheets/regular-expressions/), para un resumen de las posibilidades de las expresiones regulares.
#
# También podemos acceder a un tester para probar todo tipo de patrones en [RegExr: Learn, Build, & Test RegEx](https://regexr.com/)

# %%
#Quitar links
texto_limpio = re.sub(r'\([^)]*\)',' ',texto_limpio)
# Quitar paréntesis redondos y cuadrados después de quitar links
texto_limpio = re.sub(r'[\[\]\(\)]','',texto_limpio)
# Quitar saltos de línea
texto_limpio = re.sub(r'\n',' ',texto_limpio)
# Quitar asteriscos
texto_limpio = re.sub(r'\*',' ',texto_limpio)
# Quitar comillas sencillas y reemplazar por dobles
texto_limpio = re.sub(r"[\\']",'\'',texto_limpio)
# Quitar todo lo que no tenga punto al final, después del punto final.
texto_limpio = re.sub(r'([^.]*$)','',texto_limpio)
# Quitar Espacios extra (dos o más)
texto_limpio = re.sub('\s\s+', ' ',texto_limpio)
# Quitar el patrón . , [texto]
texto_limpio = re.sub('\.\s,\s', '. ',texto_limpio)
# Algunos países tienen prob
texto_limpio = re.sub(u'\\\'xa0','',texto_limpio)
# Quitar espacios iniciales y finales
texto_limpio = texto_limpio.strip()
texto_limpio
# Out:
# 'Tal y como lo había anunciado EL TIEMPO desde la semana pasada, la periodista Mábel Lara fue confirmada este lunes como la cabeza de lista del Senado por el revivido partido político Nuevo Liberalismo. " _#1 Una mujer negra, del Pacífico colombiano. Defensora de la libre empresa, libertad de expresión y opinión, derecho a las mujeres a decidir sobre su cuerpo y el rechazo a los autoritarismos. Mabel Lara asume la responsabilidad del futuro colombiano_ ", escribió el candidato presidencial de la colectividad, Juan Manuel Galán. . Además del estreno en la política de la columnista y presentadora, la lista del partido fundado por Luis Carlos Galán está llena de sorpresas. Una de las más grandes incógnitas era si Carlos Fernando Galán, quien renunció el viernes al Concejo de Bogotá se iba o no a lanzar al Congreso. La respuesta es sí: va a ir con el número 6. "#6 Mi hermano, sí. Coherente, valiente, fiel y leal a los principios fundadores del Nuevo Liberalismo. Un líder al servicio del interés colectivo por encima del individual. Carlos Fernando Galán padre de Julieta y de Juan Pablo, mi ahijado, padrino de mi hijo Manuel", escribió Juan Manuel en su cuenta de Twitter. . Las 4 posiciones previas serán ocupadas por el exdefensor del pueblo, Carlos Negret, quien además fue el secretario general del Partido de La U; la politóloga, columnista y docente, Sandra Borda ; el abogado, comunicador social y consultor, Guillermo Pérez Flórez; y la defensora de DD.HH. e integrante de la Mesa Nacional de Víctimas, Yolanda Perea. . En su columna habitual de los fines de semana, Juan Manuel Galán había asegurado que quienes forman parte de sus listas al Congreso “son un conjunto de obreros de la democracia que se mantienen fieles a los valores liberales y de justicia social” y que los ciudadanos que presentaron sus nombres para ser candidatos “tienen las cualidades y condiciones para servir a un pueblo que exige un Congreso renovado”. Este lunes dijo que cada uno de los 15 candidatos a la lista del Senado del Nuevo Liberalismo "se han comprometido con 10 causas claras con la urgencia de corregir las injusticias sociales y económicas en Colombia". .'

# %% [markdown]
# ### Uniendo piezas

# %%
noticia_elegida = np.random.randint(len(noticias))
# url de la noticia elegida
url = noticias[noticia_elegida]['url']
# nombre del sitio de la noticia
medio = noticias[noticia_elegida]['site_name']
# Titular de la noticia
titular = noticias[noticia_elegida]['title']
# Obtener conexión
res = requests.get(url)
# Extraer contenido
html_page = res.content
# Parsing del contenido en forma de árbol
soup = BeautifulSoup(html_page, 'html.parser')
# En caso de que tengamos que ir más profundo en la fuente
#print(soup.prettify())

# Info Básica
print(medio,titular,url,sep='\n\n',end='\n\n')

# Cuando se tiene error 403
if re.search('403',str(res)):
    print('\nNo se puede mirar ésta Noticia... Estado de la petición:', res)
    print(f'\nLe recomendamos chequear el link para ver qué ocurrió.')
    texto = []
# Sirve para El Tiempo
elif re.search(re.compile('Tiempo|ElTiempo'),titular):
    texto = soup.find_all('p',{'class': 'contenido'})
# Sirve Para Portafolio  
elif re.search('Portafolio',titular):
    texto = soup.find_all('p',{'class': 'parrafo'})
# Sirve para CNN, Antena 2, NTN24, MARCA,...
elif re.search(re.compile('CNN|Antena|NTN24|Marca|La Silla Vacia|'\
                           +'El Carro Colombiano|FutbolRed|vanguardia|'\
                           +'RT|ENTER|infobae|Gizmodo|Conversation|Independent|'\
                           +'Mundo Deportivo|Tendencias21|Noticias de Israel|'\
                           +'Kudasai|notimerica|El Confidencial|BBC Mundo|Diario Depor|El Universal'),titular):
    texto = soup.find_all('p')
# Sirve para Yahoo
elif re.search(re.compile('Yahoo'),titular):
    texto = soup.find_all('div',{'class': 'caas-body'})
# Sirve para Caracol Radio, eliminar Basura
elif re.search(re.compile('Caracol Radio'),titular):
    texto = soup.find_all('p')
    # Todas las noticias de CR comienzan con negrita (Hasta ahora)
    p = re.compile('^[^\*]*\*')
    # Quitar Las propagandas del inicio
    texto = re.sub(p,'',''.join(str(texto)))
# Sirve para El Espectador sin el encabezado de resumen.
elif re.search(re.compile('Espectador|ESPECTADOR'),titular):
    texto = soup.find_all('p',{'class': 'font--secondary'})
# Sirve para W-Radio
elif re.search(re.compile('W-Radio'),titular):
    texto = soup.find_all('div',{'class': 'cnt-txt'})
# Sirve para el Colombiano
elif re.search(re.compile('El Colombiano'),titular):
    texto = soup.find_all('div',{'class': 'block-text'})
# Sirve para Pulzo.com
elif re.search(re.compile('Pulzo'),titular):
    texto = soup.find_all('section',{'class': 'article-body-left'})
# Sirve para Blu Radio, pero NO SE DEJA MINAR -> Error 403 de conexión
elif re.search(re.compile('Blu'),titular):
    texto = soup.find_all('div',{'class': 'RichTextArticleBody-body RichTextBody'})
# Sirve para Bogota.gov.co
elif re.search(re.compile('Bogota'),titular):
    texto = soup.find_all('div',{'class': 'article__content'})
# Sirve para El País
elif re.search(re.compile('elpais|El País|EL PAÍS'),titular):
    # A veces sirve este
    #texto = soup.find_all('p',{'class': 'epigraph paragraph'})
    texto = soup.find_all('p')
# Sirve para La República
elif re.search(re.compile('República'),titular):
    texto = soup.find_all('div',{'class': 'html-content'})
# Sirve para DW.COM
elif re.search(re.compile('Deutsche'),titular):
    texto = soup.find_all('div',{'class': 'longText'})
# Sirve para Sputnik
elif re.search(re.compile('Sputnik'),titular):
    texto = soup.find_all('div',{'class': 'article__announce-text'})
# Sirve para Revista Semana (IOY)
elif re.search(re.compile('Semana'),titular):
    #texto = soup.find_all('p',{'class': 'section sp-8'})
    #texto = soup.find_all('article',{'class': 'paywall'})
    texto = soup.find_all('script',{'id':'fusion-metadata'})
    # Encontrar dentro del script la parte de , "content":"...
    p=re.compile('([^,\"*]*\w+\s[^\"]*\.)')
    # Encontrar texto escondido
    texto= p.findall(''.join(str(texto)))
    # Chambonada chévere, quitar partes finales (No creo que siempre funcione)
    texto = [re.sub(re.compile(r'\b(Últimas)\b.*|\b(últimas)\b.*|\b(Noticias)\b.*|\b(Nación)\b.*|\b(Revista Semana)\b.*'),'',token) for token in texto]
    texto = ''.join(texto)
else:
    print("Medio de comunicación no reconocido. Los resultados pueden salirse de lo esperado.")
    texto = []
    
#print(texto)


# Convertit HTML a Texto    
texto_limpio = html2text.html2text(''.join(str(texto)))
#Quitar links
texto_limpio = re.sub(r'\([^)]*\)',' ',texto_limpio)
# Quitar paréntesis redondos y cuadrados después de quitar links
texto_limpio = re.sub(r'[\[\]\(\)]','',texto_limpio)
# Quitar saltos de línea
texto_limpio = re.sub(r'\n',' ',texto_limpio)
# Quitar asteriscos
texto_limpio = re.sub(r'\*',' ',texto_limpio)
# Quitar comillas sencillas y reemplazar por dobles
texto_limpio = re.sub(r"[\\']",'\'',texto_limpio)
# Especial para el Colombiano, se mezclan noticias después de >
#texto_limpio = re.sub(r'(>[^>]*$)','',texto_limpio)
#Quitar todo lo que no tenga punto al final, después del punto final.
texto_limpio = re.sub(r'([^.]*$)','',texto_limpio)
# Quitar Espacios extra (dos o más)
texto_limpio = re.sub('\s\s+', ' ',texto_limpio)
# Quitar el patrón . , texto
texto_limpio = re.sub('\.\s,\s', '. ',texto_limpio)
# Quitar ARTICULOS RELACIONADOS, LA REPÚBLICA
texto_limpio = re.sub('ARTÍCULO RELACIONADO! ##', '',texto_limpio)
# CNN Derechos de Autor
# No es muy elegante. Toca elaborar más.
p = re.compile('© 2021 Cable News Network. A Warner Media Company. All Rights Reserved. CNN Sans ™ & © 2021 Cable News Network.')
# Quitar Las propagandas del inicio
texto_limpio = re.sub(p,'',texto_limpio)
# Quitar espacios iniciales y finales
texto_limpio = texto_limpio.strip()

if texto_limpio:
    print(texto_limpio)
elif not re.search('403',str(res)):
    print('\nNo se puede mirar ésta Noticia...')
    print(f'\nLe recomendamos chequear el link para ver qué ocurrió.')
# Out:
# El País
#
# Una investigación de la ONU concluye que la policía colombiana mató a 11 jóvenes en las protestas de Bogotá - EL PAÍS
#
# https://elpais.com/internacional/2021-12-13/una-investigacion-de-la-onu-concluye-que-la-policia-colombiana-mato-a-11-jovenes-en-las-protestas-de-bogota.html
#
# “No puede llamarse de otra manera”. El informe independiente de esclarecimiento apoyado por el Sistema de Naciones Unidas sobre lo ocurrido en Bogotá los días 9 y 10 de septiembre de 2020 ha dicho con todas las letras que lo que vivió la ciudad esos dos días cuando se desataron unas protestas ciudadanas por el asesinato del abogado Javier Ordóñez durante un operativo por parte de agentes fue una masacre policial. “La policía nacional reaccionó de forma desproporcionada, ilegal y apartada del principio de humanidad en la atención de las manifestaciones ciudadanas de Bogotá y Soacha. Su actuación causó una masacre que acabó con las vidas de 11 jóvenes”, dijo Carlos Negret, ex defensor del pueblo y coordinador de la investigación. La investigación —solicitada por la alcaldesa de Bogotá, Claudia López — determinó que la masacre ocurrió debido a la “ausencia de una orden política y operativa de no utilizar las armas de fuego en contra de los manifestantes”. Es decir, que faltó un mayor liderazgo “político y operativo” tanto del Gobierno de Iván Duque como el de López para evitar que ocurriera. La alcaldesa se refirió al informe como “doloroso hasta el alma”. Con la voz entrecortada y entre lágrimas, López ofreció disculpas a las familias y amigos de los jóvenes asesinados. “Ofrezco perdón como ciudadana y como alcaldesa por no haber podido prevenir que una tragedia semejante ocurriera. Todos nos equivocamos”, dijo este lunes. La ‘Relatoría de esclarecimiento del 9S’ también alerta de que, dada la falta de avance en las investigaciones, no es posible garantizar que no se repita. “A 15 meses de la ocurrencia de los hechos, los avances son residuales y si bien no es posible aseverar que se encuentran en la impunidad, hacia allá transitarán si no se adoptan medidas urgentes”, concluye el informe. Los investigadores documentaron 14 asesinatos en el contexto de las protestas, incluido el de Ordóñez, de los cuales 11 habrían sido a manos de agentes de la Policía, en lo que consideraron “uno de los episodios más graves de violaciones a los derechos humanos en la historia de la ciudad”. El informe advierte también que otros dos asesinatos ocurrieron por personas vestidas de civil que dispararon contra manifestantes. Pero la masacre pudo ser mayor. La investigación documentó también que 75 personas resultaron heridas por arma de fuego, 187 por armas cortopunzantes, así como las heridas contra 216 agentes de la Policía. En total, dice el documento, se encontraron siete prácticas violentas en el contexto de las manifestaciones: uso ilícito de la fuerza, violencia contra la fuerza pública, detenciones arbitrarias, violencias basadas en género, estigmatización de la protesta social, violencia contra bienes públicos y privados e impunidad. Juliette de Riveros, Representante de la Alta Comisionada para los derechos humanos de la Organización de las Naciones Unidas , dijo que el objetivo del informe “no es desacreditar a la policía, ni ensuciar su imagen, por el contrario el objetivo es restaurar la confianza, utilizando la verdad”. “Se plantea una situación de desconfianza grave en la institucionalidad y en la Policía”, dijo Riveros pero dijo que es necesario hacer investigaciones rápidas y creíbles, sanciones inequívocas contra quienes abusaron, reconociendo la verdad y a las víctimas y haciendo ajustes doctrinales necesarios a la Policía. Suscríbase aquí a la newsletter de EL PAÍS América y reciba todas las claves informativas de la actualidad de la región , Corresponsal de EL PAÍS en Colombia. Periodista y librohólica hasta los tuétanos. Comunicadora de la Universidad Pontificia Bolivariana y Magister en Relaciones Internacionales de Flacso. Ha recibido el Premio Gabo 2018, con el trabajo colectivo Venezuela a la fuga, y otros reconocimientos. Coautora del Periodismo para cambiar el Chip de la guerra.

# %%
traductor = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")

# %%
frases = split_into_sentences(texto_limpio)
print(f"{len(frases)} Frases encontradas.")
# Out:
# 24 Frases encontradas.

# %%
traducciones_frases = traductor(frases)

# %%
traduccion = [traduccion['translation_text'] for traduccion in traducciones_frases]
traduccion = ' '.join(traduccion)
traduccion
# Out:
# '“It cannot be called otherwise.” The independent report of clarification supported by the United Nations system on what happened in Bogotá on September 9 and 10, 2020, has said with all the letters that what the city experienced those two days when citizen protests broke out over the murder of lawyer Javier Ordognez during an operation by agents was a police massacre. “The national police reacted disproportionately, illegally and away from the principle of humanity in the attention of the citizens’ demonstrations in Bogotá and Soacha. His action caused a massacre that killed 11 young people,” said Carlos Negret, a former ombudsman and coordinator of the investigation. The investigation, requested by Bogotá’s mayor Claudia López, determined that the massacre occurred due to the “absence of a political and operational order not to use firearms against protesters.” That is to say, there was a lack of greater “political and operational” leadership from both the Government of Iván Duque and López to prevent it from happening. The mayor referred to the report as “painful to the soul.” López apologized to the families and friends of the murdered youth with his voice cut in tears. “I offer forgiveness as a citizen and mayor for not being able to prevent such a tragedy from happening. We were all wrong,” he said this Monday. The ‘9S Clarification Rapporteurship’ also warns that, given the lack of progress in investigations, it is not possible to ensure that it is not repeated. “15 months after the occurrence of the events, the progress is residual and although it is not possible to claim that they are in impunity, they will travel there if urgent measures are not taken,” the report concludes. Investigators documented 14 murders in the context of the protests, including that of Ordonez, of which 11 were reportedly at the hands of police officers, in what they considered “one of the most serious episodes of human rights violations in the history of the city.” The report also warns that two other murders occurred by civilians who shot at demonstrators. But the massacre could have been greater. The investigation also documented that 75 people were injured by firearms, 187 by sharp weapons, as well as injuries to 216 police officers. In total, the document says, seven violent practices were found in the context of demonstrations: unlawful use of force, violence against public forces, arbitrary detentions, gender-based violence, stigmatization of social protest, violence against public and private property and impunity. Juliette de Riveros, Representative of the United Nations High Commissioner for Human Rights, said that the aim of the report “is not to discredit the police, nor to dirty their image, on the contrary the aim is to restore confidence, using the truth”. “There is a situation of serious distrust in the institutions and the police,” Riveros said, but he said that there is a need for prompt and credible investigations, unequivocal sanctions against those who abused, recognizing the truth and the victims, and making necessary doctrinal adjustments to the police. Subscribe here to the newsletter of EL PAÍS América and receive all the information keys of the current situation in the region , Correspondent of EL PAÍS in Colombia. Journalist and librohólica to the tuetanos. Communicator of the Universidad Pontificia Bolivariana y Magister en Relaciones Internacionales de Flacso. He has received the 2018 Gabo Prize, with collective work Venezuela to escape, and other recognitions. Co-author of Journalism to change the Chip of War.'

# %%
sumarizer = pipeline('summarization',min_length=100)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)

# %%
resumen = sumarizer(traduccion)

# %%
resumen_en = resumen[0]['summary_text']
resumen_en
# Out:
# ' Independent report of clarification supported by U.N system on what happened in Bogotá on September 9 and 10, 2020 . Investigation determined that the massacre occurred due to the “absence of a political and operational order not to use firearms against protesters . Investigators documented 14 murders in the context of the protests, including that of lawyer Javier Ordonez, of which 11 were reportedly at the hands of police officers . Report also documented that 75 people were injured by firearms, 187 by sharp weapons, as well as injuries to 216 police officers.'

# %%
traductor_en_es = pipeline("translation", model="Helsinki-NLP/opus-mt-en-es")

# %%
resumen_es = traductor_en_es(resumen_en)

# %%
resumen_final = resumen_es[0]['translation_text']
resumen_final
# Out:
# 'Informe independiente de aclaración apoyado por el sistema de las Naciones Unidas sobre lo ocurrido en Bogotá el 9 y 10 de septiembre de 2020 . Investigación determinó que la masacre se produjo debido a la “ausencia de una orden política y operativa para no usar armas de fuego contra los manifestantes . Investigadores documentaron 14 asesinatos en el contexto de las protestas, incluyendo el del abogado Javier Ordonez, de los cuales 11 fueron presuntamente a manos de agentes de policía . Informe también documentó que 75 personas fueron heridas por armas de fuego, 187 por armas punzantes, así como lesiones a 216 agentes de policía.'

# %% [markdown]
# ## Transformer en Español Nativo

# %%
import torch
from transformers import BertTokenizerFast, EncoderDecoderModel
device = 'cuda' if torch.cuda.is_available() else 'cpu'
ckpt = 'mrm8488/bert2bert_shared-spanish-finetuned-summarization'
tokenizer = BertTokenizerFast.from_pretrained(ckpt)
model = EncoderDecoderModel.from_pretrained(ckpt).to(device)

# %%
def generate_summary(text,min_length=None):

    inputs = tokenizer([text], padding="max_length", truncation=True, max_length=512, return_tensors="pt")
    input_ids = inputs.input_ids.to(device)
    attention_mask = inputs.attention_mask.to(device)
    output = model.generate(input_ids, attention_mask=attention_mask,min_length=min_length)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
generate_summary(texto_limpio)
